# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("CocaCola_Sales_Rawdata.xlsx")
df
# Out:
#    Quarter        Sales
# 0    Q1_86  1734.827000
# 1    Q2_86  2244.960999
# 2    Q3_86  2533.804993
# 3    Q4_86  2154.962997
# 4    Q1_87  1547.818996
# 5    Q2_87  2104.411995
# 6    Q3_87  2014.362999
# 7    Q4_87  1991.746998
# 8    Q1_88  1869.049999
# 9    Q2_88  2313.631996
# 10   Q3_88  2128.320000
# 11   Q4_88  2026.828999
# 12   Q1_89  1910.603996
# 13   Q2_89  2331.164993
# 14   Q3_89  2206.549995
# 15   Q4_89  2173.967995
# 16   Q1_90  2148.278000
# 17   Q2_90  2739.307999
# 18   Q3_90  2792.753998
# 19   Q4_90  2556.009995
# 20   Q1_91  2480.973999
# 21   Q2_91  3039.522995
# 22   Q3_91  3172.115997
# 23   Q4_91  2879.000999
# 24   Q1_92  2772.000000
# 25   Q2_92  3550.000000
# 26   Q3_92  3508.000000
# 27   Q4_92  3243.859993
# 28   Q1_93  3056.000000
# 29   Q2_93  3899.000000
# 30   Q3_93  3629.000000
# 31   Q4_93  3373.000000
# 32   Q1_94  3352.000000
# 33   Q2_94  4342.000000
# 34   Q3_94  4461.000000
# 35   Q4_94  4017.000000
# 36   Q1_95  3854.000000
# 37   Q2_95  4936.000000
# 38   Q3_95  4895.000000
# 39   Q4_95  4333.000000
# 40   Q1_96  4194.000000
# 41   Q2_96  5253.000000

# %%
df['Month'] = pd.to_datetime(df['Quarter'].str[-2:] + df['Quarter'].str[:2])

# %%
df
# Out:
#    Quarter        Sales      Month
# 0    Q1_86  1734.827000 2086-01-01
# 1    Q2_86  2244.960999 2086-04-01
# 2    Q3_86  2533.804993 2086-07-01
# 3    Q4_86  2154.962997 2086-10-01
# 4    Q1_87  1547.818996 2087-01-01
# 5    Q2_87  2104.411995 2087-04-01
# 6    Q3_87  2014.362999 2087-07-01
# 7    Q4_87  1991.746998 2087-10-01
# 8    Q1_88  1869.049999 2088-01-01
# 9    Q2_88  2313.631996 2088-04-01
# 10   Q3_88  2128.320000 2088-07-01
# 11   Q4_88  2026.828999 2088-10-01
# 12   Q1_89  1910.603996 2089-01-01
# 13   Q2_89  2331.164993 2089-04-01
# 14   Q3_89  2206.549995 2089-07-01
# 15   Q4_89  2173.967995 2089-10-01
# 16   Q1_90  2148.278000 2090-01-01
# 17   Q2_90  2739.307999 2090-04-01
# 18   Q3_90  2792.753998 2090-07-01
# 19   Q4_90  2556.009995 2090-10-01
# 20   Q1_91  2480.973999 2091-01-01
# 21   Q2_91  3039.522995 2091-04-01
# 22   Q3_91  3172.115997 2091-07-01
# 23   Q4_91  2879.000999 2091-10-01
# 24   Q1_92  2772.000000 2092-01-01
# 25   Q2_92  3550.000000 2092-04-01
# 26   Q3_92  3508.000000 2092-07-01
# 27   Q4_92  3243.859993 2092-10-01
# 28   Q1_93  3056.000000 2093-01-01
# 29   Q2_93  3899.000000 2093-04-01
# 30   Q3_93  3629.000000 2093-07-01
# 31   Q4_93  3373.000000 2093-10-01
# 32   Q1_94  3352.000000 2094-01-01
# 33   Q2_94  4342.000000 2094-04-01
# 34   Q3_94  4461.000000 2094-07-01
# 35   Q4_94  4017.000000 2094-10-01
# 36   Q1_95  3854.000000 2095-01-01
# 37   Q2_95  4936.000000 2095-04-01
# 38   Q3_95  4895.000000 2095-07-01
# 39   Q4_95  4333.000000 2095-10-01
# 40   Q1_96  4194.000000 2096-01-01
# 41   Q2_96  5253.000000 2096-04-01

# %%
df.shape
# Out:
# (42, 3)

# %%
df["month"]= df.Month.dt.strftime("%b") #month extraction

# %%
df["year"]= df.Month.dt.strftime("%Y")   #year extraction

# %%
df
# Out:
#    Quarter        Sales      Month month  year
# 0    Q1_86  1734.827000 2086-01-01   Jan  2086
# 1    Q2_86  2244.960999 2086-04-01   Apr  2086
# 2    Q3_86  2533.804993 2086-07-01   Jul  2086
# 3    Q4_86  2154.962997 2086-10-01   Oct  2086
# 4    Q1_87  1547.818996 2087-01-01   Jan  2087
# 5    Q2_87  2104.411995 2087-04-01   Apr  2087
# 6    Q3_87  2014.362999 2087-07-01   Jul  2087
# 7    Q4_87  1991.746998 2087-10-01   Oct  2087
# 8    Q1_88  1869.049999 2088-01-01   Jan  2088
# 9    Q2_88  2313.631996 2088-04-01   Apr  2088
# 10   Q3_88  2128.320000 2088-07-01   Jul  2088
# 11   Q4_88  2026.828999 2088-10-01   Oct  2088
# 12   Q1_89  1910.603996 2089-01-01   Jan  2089
# 13   Q2_89  2331.164993 2089-04-01   Apr  2089
# 14   Q3_89  2206.549995 2089-07-01   Jul  2089
# 15   Q4_89  2173.967995 2089-10-01   Oct  2089
# 16   Q1_90  2148.278000 2090-01-01   Jan  2090
# 17   Q2_90  2739.307999 2090-04-01   Apr  2090
# 18   Q3_90  2792.753998 2090-07-01   Jul  2090
# 19   Q4_90  2556.009995 2090-10-01   Oct  2090
# 20   Q1_91  2480.973999 2091-01-01   Jan  2091
# 21   Q2_91  3039.522995 2091-04-01   Apr  2091
# 22   Q3_91  3172.115997 2091-07-01   Jul  2091
# 23   Q4_91  2879.000999 2091-10-01   Oct  2091
# 24   Q1_92  2772.000000 2092-01-01   Jan  2092
# 25   Q2_92  3550.000000 2092-04-01   Apr  2092
# 26   Q3_92  3508.000000 2092-07-01   Jul  2092
# 27   Q4_92  3243.859993 2092-10-01   Oct  2092
# 28   Q1_93  3056.000000 2093-01-01   Jan  2093
# 29   Q2_93  3899.000000 2093-04-01   Apr  2093
# 30   Q3_93  3629.000000 2093-07-01   Jul  2093
# 31   Q4_93  3373.000000 2093-10-01   Oct  2093
# 32   Q1_94  3352.000000 2094-01-01   Jan  2094
# 33   Q2_94  4342.000000 2094-04-01   Apr  2094
# 34   Q3_94  4461.000000 2094-07-01   Jul  2094
# 35   Q4_94  4017.000000 2094-10-01   Oct  2094
# 36   Q1_95  3854.000000 2095-01-01   Jan  2095
# 37   Q2_95  4936.000000 2095-04-01   Apr  2095
# 38   Q3_95  4895.000000 2095-07-01   Jul  2095
# 39   Q4_95  4333.000000 2095-10-01   Oct  2095
# 40   Q1_96  4194.000000 2096-01-01   Jan  2096
# 41   Q2_96  5253.000000 2096-04-01   Apr  2096

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,8))
heatmap_y_month = pd.pivot_table(data=df,values='Sales',index='year',columns='month',fill_value=0)
sns.heatmap(heatmap_y_month,annot=True,fmt ="g") #fmt is format of grid value
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
heatmap_y_month
# Out:
# month          Apr          Jan          Jul          Oct
# year
# 2086   2244.960999  1734.827000  2533.804993  2154.962997
# 2087   2104.411995  1547.818996  2014.362999  1991.746998
# 2088   2313.631996  1869.049999  2128.320000  2026.828999
# 2089   2331.164993  1910.603996  2206.549995  2173.967995
# 2090   2739.307999  2148.278000  2792.753998  2556.009995
# 2091   3039.522995  2480.973999  3172.115997  2879.000999
# 2092   3550.000000  2772.000000  3508.000000  3243.859993
# 2093   3899.000000  3056.000000  3629.000000  3373.000000
# 2094   4342.000000  3352.000000  4461.000000  4017.000000
# 2095   4936.000000  3854.000000  4895.000000  4333.000000
# 2096   5253.000000  4194.000000     0.000000     0.000000

# %%
heatmap_y_month.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
plt.figure(figsize=(24,7))
df.Sales.plot(label="org")
for i in range(2,24,4):
  df['Sales'].rolling(i).mean().plot(label=str(i))
  plt.legend(loc='best')

# %%
# ACF plots and PACF plots
import statsmodels.graphics.tsaplots as tsa_plots
tsa_plots.plot_acf(df.Sales,lags=12)
tsa_plots.plot_pacf(df.Sales,lags=12)
plt.show()
# Out:
# C:\Users\atom\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
#boxplot for ever
plt.figure(figsize=(8,6))
#plt subplot
sns.boxplot(x="month",y="Sales",data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='Sales'>

# %%
#boxplot for ever
plt.figure(figsize=(8,6))
#plt subplot
sns.boxplot(x="year",y="Sales",data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='Sales'>

# %%
plt.figure(figsize=(12,3))
sns.lineplot(x="year",y="Sales",data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='Sales'>

# %%
df.Sales.plot()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8,6))
df.groupby('year')['Sales'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
plt.figure(figsize=(8,6))
df.groupby('month')['Sales'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='month'>

# %%
#Time series decomposition plot
from statsmodels.tsa.seasonal import seasonal_decompose
decompose_ts_add = seasonal_decompose(df.Sales,period=12)
decompose_ts_add.plot()
plt.show()

# %%
df_trans=df.copy()

# %%
df_trans['t']= np.arange(1,43)

# %%
df_trans['log']= np.log(df['Sales']) #log transform of data

# %%
df_trans['t_sq']= df['Sales']*df['Sales'] # taking sq

# %%
df_trans
# Out:
#    Quarter        Sales      Month month  year   t       log          t_sq
# 25   Q2_92  3550.000000 2092-04-01   Apr  2092  26  8.174703  1.260250e+07
# 26   Q3_92  3508.000000 2092-07-01   Jul  2092  27  8.162801  1.230606e+07
# 27   Q4_92  3243.859993 2092-10-01   Oct  2092  28  8.084519  1.052263e+07
# 28   Q1_93  3056.000000 2093-01-01   Jan  2093  29  8.024862  9.339136e+06

# %%
test= df_trans.tail(int(len(df_trans['Sales'])-len(train)))

# %%
test
# Out:
#    Quarter   Sales      Month month  year   t       log        t_sq
# 29   Q2_93  3899.0 2093-04-01   Apr  2093  30  8.268475  15202201.0
# 30   Q3_93  3629.0 2093-07-01   Jul  2093  31  8.196712  13169641.0
# 31   Q4_93  3373.0 2093-10-01   Oct  2093  32  8.123558  11377129.0
# 32   Q1_94  3352.0 2094-01-01   Jan  2094  33  8.117312  11235904.0
# 33   Q2_94  4342.0 2094-04-01   Apr  2094  34  8.376090  18852964.0
# 34   Q3_94  4461.0 2094-07-01   Jul  2094  35  8.403128  19900521.0
# 35   Q4_94  4017.0 2094-10-01   Oct  2094  36  8.298291  16136289.0
# 36   Q1_95  3854.0 2095-01-01   Jan  2095  37  8.256867  14853316.0
# 37   Q2_95  4936.0 2095-04-01   Apr  2095  38  8.504311  24364096.0
# 38   Q3_95  4895.0 2095-07-01   Jul  2095  39  8.495970  23961025.0
# 39   Q4_95  4333.0 2095-10-01   Oct  2095  40  8.374015  18774889.0
# 40   Q1_96  4194.0 2096-01-01   Jan  2096  41  8.341410  17589636.0
# 41   Q2_96  5253.0 2096-04-01   Apr  2096  42  8.566555  27594009.0

# %%
#model buildings

# %%
import statsmodels.formula.api as smf

# %%
#linear model
linear_model=smf.ols('Sales~t',data=train).fit()
pred_linear= pd.Series(linear_model.predict(pd.DataFrame(test['t'])))
rmse_linear=np.sqrt(np.mean((np.array(test['Sales'])-np.array(pred_linear))**2))
rmse_linear
# Out:
# 799.028903991488

# %%
print('predicted data')
pred_linear.head(10)
# Out:
# predicted data
# 29    3226.897262
# 30    3278.288484
# 31    3329.679706
# 32    3381.070928
# 33    3432.462150
# 34    3483.853373
# 35    3535.244595
# 36    3586.635817
# 37    3638.027039
# 38    3689.418261
# dtype: float64

# %%
print('original data')
test['Sales'].head(10)
# Out:
# original data
# 29    3899.0
# 30    3629.0
# 31    3373.0
# 32    3352.0
# 33    4342.0
# 34    4461.0
# 35    4017.0
# 36    3854.0
# 37    4936.0
# 38    4895.0
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(8,6))
plt.title('Plot of predicted data vs original data')
plt.plot(test['Sales'],color='r')
plt.plot(pred_linear, )

# %%
#quadratic
Quad = smf.ols('Sales~t+t_sq',data=train).fit()
pred_Quad = pd.Series(Quad.predict(test[['t','t_sq']]))
rmse_Quad=np.sqrt(np.mean((np.array(test['Sales'])-np.array(pred_Quad))**2))
rmse_Quad
# Out:
# 580.9914378027482

# %%
print('predicted data')
pred_Quad.head(10)
# Out:
# predicted data
# 29    4143.910097
# 30    3768.171688
# 31    3437.068797
# 32    3413.013045
# 33    4831.564916
# 34    5028.556209
# 35    4330.823541
# 36    4094.466441
# 37    5865.144446
# 38    5792.399965
# dtype: float64

# %%
plt.figure(figsize=(8,6))
plt.title('Plot of predicted data vs original data')
plt.plot(test['Sales'],color='r')
plt.plot(pred_Quad, )

# %%
#exponential
exp= smf.ols('log~t',data=train).fit()
pred_exp= pd.Series(exp.predict(pd.DataFrame(test['t'])))
rmse_exp=np.sqrt(np.mean((np.array(test['Sales'])-np.array(np.exp(pred_exp)))**2))
rmse_exp
# Out:
# 637.5585943826359

# %%
print('predicted data')
pred_exp.head(10)
# Out:
# predicted data
# 29    8.092446
# 30    8.112987
# 31    8.133528
# 32    8.154069
# 33    8.174611
# 34    8.195152
# 35    8.215693
# 36    8.236234
# 37    8.256775
# 38    8.277317
# dtype: float64

# %%
print('original data')
test['Sales'].head(10)
# Out:
# original data
# 29    3899.0
# 30    3629.0
# 31    3373.0
# 32    3352.0
# 33    4342.0
# 34    4461.0
# 35    4017.0
# 36    3854.0
# 37    4936.0
# 38    4895.0
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(8,6))
plt.title('Plot of predicted data vs original data')
plt.plot(test['Sales'],color='r')
plt.plot(pred_exp, )

# %%
#log with Sq
exp= smf.ols('log~t+t_sq',data=train).fit()
pred_log_sq= pd.Series(exp.predict(test[['t','t_sq']]))
rmse_log_sq=np.sqrt(np.mean((np.array(test['log'])-np.array(pred_log_sq))**2))
rmse_log_sq
# Out:
# 0.38401316683725495

# %%
print('predicted data')
pred_log_sq.head(10)
# Out:
# predicted data
# 29    8.444445
# 30    8.301031
# 31    8.174750
# 32    8.166330
# 33    8.711662
# 34    8.788093
# 35    8.521079
# 36    8.431167
# 37    9.111664
# 38    9.084555
# dtype: float64

# %%
plt.figure(figsize=(8,6))
plt.title('Plot of predicted data vs original data')
plt.plot(test['log'],color='r')
plt.plot(pred_log_sq, )

# %%
#compare result
data={"MODEL":pd.Series(["rmse_linear","rmse_Quad","rmse_exp","rmse_log_sq"]),"RMSE_Values":pd.Series
      ([rmse_linear,rmse_Quad,rmse_exp,rmse_log_sq])}

# %%
type(data)
# Out:
# dict

# %%
table_rmse = pd.DataFrame(data)
table_rmse.sort_values(['RMSE_Values'])
# Out:
#          MODEL  RMSE_Values
# 3  rmse_log_sq     0.384013
# 1    rmse_Quad   580.991438
# 2     rmse_exp   637.558594
# 0  rmse_linear   799.028904

# %%
#predicting new data
df_trans
# Out:
#    Quarter        Sales      Month month  year   t       log          t_sq
# 0    Q1_86  1734.827000 2086-01-01   Jan  2086   1  7.458663  3.009625e+06
# 1    Q2_86  2244.960999 2086-04-01   Apr  2086   2  7.716443  5.039850e+06
# 2    Q3_86  2533.804993 2086-07-01   Jul  2086   3  7.837477  6.420168e+06
# 3    Q4_86  2154.962997 2086-10-01   Oct  2086   4  7.675529  4.643866e+06
# 4    Q1_87  1547.818996 2087-01-01   Jan  2087   5  7.344602  2.395744e+06
# 5    Q2_87  2104.411995 2087-04-01   Apr  2087   6  7.651791  4.428550e+06
# 40   Q1_96  4194.000000 2096-01-01   Jan  2096  41  8.341410  1.758964e+07
# 41   Q2_96  5253.000000 2096-04-01   Apr  2096  42  8.566555  2.759401e+07

# %%
#Build model on entire data set
model_full= smf.ols('log~t+t_sq',data=df_trans).fit()

# %%
pred_new  = pd.Series(np.exp(model_full.predict(df_trans)))
pred_new
# Out:
# 0     1881.898498
# 1     2022.364801
# 2     2130.560127
# 3     2038.058968
# 4     1921.654076
# 5     2065.250722
# 6     2062.318664
# 7     2077.113572
# 8     2067.655147
# 9     2210.422238
# 10    2176.975322
# 11    2170.509851
# 12    2161.688559
# 13    2305.611855
# 14    2288.683547
# 15    2301.432044
# 16    2316.494581
# 17    2555.600348
# 18    2604.509889
# 19    2530.582896
# 20    2526.444562
# 21    2803.866178
# 22    2904.023596
# 23    2778.164760
# 24    2754.464252
# 25    3233.323103
# 26    3236.090529
# 27    3094.916177
# 28    3014.690668
# 29    3642.468197
# 30    3457.134779
# 31    3305.400129
# 32    3323.964505
# 33    4237.382633
# 34    4418.896387
# 35    3977.795546
# 36    3862.917922
# 37    5217.954009
# 38    5205.422448
# 39    4486.478527
# 40    4369.946029
# 41    5992.587926
# dtype: float64

# %%
rmse123=np.sqrt(np.mean((np.array(df_trans['Sales'])-np.array(pred_new))**2))
rmse123
# Out:
# 211.94731935566767

# %%
df_trans['predictions']=pred_new

# %%
df_trans
# Out:
#    Quarter        Sales      Month month  year   t       log          t_sq  \
# 0    Q1_86  1734.827000 2086-01-01   Jan  2086   1  7.458663  3.009625e+06
# 1    Q2_86  2244.960999 2086-04-01   Apr  2086   2  7.716443  5.039850e+06
# 2    Q3_86  2533.804993 2086-07-01   Jul  2086   3  7.837477  6.420168e+06
# 3    Q4_86  2154.962997 2086-10-01   Oct  2086   4  7.675529  4.643866e+06
# 4    Q1_87  1547.818996 2087-01-01   Jan  2087   5  7.344602  2.395744e+06
# 5    Q2_87  2104.411995 2087-04-01   Apr  2087   6  7.651791  4.428550e+06
# 6    Q3_87  2014.362999 2087-07-01   Jul  2087   7  7.608058  4.057658e+06
# 7    Q4_87  1991.746998 2087-10-01   Oct  2087   8  7.596767  3.967056e+06
# 8    Q1_88  1869.049999 2088-01-01   Jan  2088   9  7.533186  3.493348e+06
# 9    Q2_88  2313.631996 2088-04-01   Apr  2088  10  7.746574  5.352893e+06
# 10   Q3_88  2128.320000 2088-07-01   Jul  2088  11  7.663088  4.529746e+06
# 11   Q4_88  2026.828999 2088-10-01   Oct  2088  12  7.614228  4.108036e+06
# 12   Q1_89  1910.603996 2089-01-01   Jan  2089  13  7.555175  3.650408e+06
# 13   Q2_89  2331.164993 2089-04-01   Apr  2089  14  7.754123  5.434330e+06
# 14   Q3_89  2206.549995 2089-07-01   Jul  2089  15  7.699185  4.868863e+06
# 15   Q4_89  2173.967995 2089-10-01   Oct  2089  16  7.684309  4.726137e+06
# 16   Q1_90  2148.278000 2090-01-01   Jan  2090  17  7.672422  4.615098e+06
# 17   Q2_90  2739.307999 2090-04-01   Apr  2090  18  7.915461  7.503808e+06
# 18   Q3_90  2792.753998 2090-07-01   Jul  2090  19  7.934783  7.799475e+06
# 19   Q4_90  2556.009995 2090-10-01   Oct  2090  20  7.846203  6.533187e+06
# 20   Q1_91  2480.973999 2091-01-01   Jan  2091  21  7.816407  6.155232e+06
# 21   Q2_91  3039.522995 2091-04-01   Apr  2091  22  8.019456  9.238700e+06
# 22   Q3_91  3172.115997 2091-07-01   Jul  2091  23  8.062154  1.006232e+07
# 23   Q4_91  2879.000999 2091-10-01   Oct  2091  24  7.965199  8.288647e+06
# 24   Q1_92  2772.000000 2092-01-01   Jan  2092  25  7.927324  7.683984e+06
# 25   Q2_92  3550.000000 2092-04-01   Apr  2092  26  8.174703  1.260250e+07
# 26   Q3_92  3508.000000 2092-07-01   Jul  2092  27  8.162801  1.230606e+07
# 27   Q4_92  3243.859993 2092-10-01   Oct  2092  28  8.084519  1.052263e+07
# 28   Q1_93  3056.000000 2093-01-01   Jan  2093  29  8.024862  9.339136e+06
# 29   Q2_93  3899.000000 2093-04-01   Apr  2093  30  8.268475  1.520220e+07
# 30   Q3_93  3629.000000 2093-07-01   Jul  2093  31  8.196712  1.316964e+07
# 31   Q4_93  3373.000000 2093-10-01   Oct  2093  32  8.123558  1.137713e+07
# 32   Q1_94  3352.000000 2094-01-01   Jan  2094  33  8.117312  1.123590e+07
# 33   Q2_94  4342.000000 2094-04-01   Apr  2094  34  8.376090  1.885296e+07
# 34   Q3_94  4461.000000 2094-07-01   Jul  2094  35  8.403128  1.990052e+07
# 35   Q4_94  4017.000000 2094-10-01   Oct  2094  36  8.298291  1.613629e+07
# 36   Q1_95  3854.000000 2095-01-01   Jan  2095  37  8.256867  1.485332e+07
# 37   Q2_95  4936.000000 2095-04-01   Apr  2095  38  8.504311  2.436410e+07
# 38   Q3_95  4895.000000 2095-07-01   Jul  2095  39  8.495970  2.396102e+07
# 39   Q4_95  4333.000000 2095-10-01   Oct  2095  40  8.374015  1.877489e+07
# 40   Q1_96  4194.000000 2096-01-01   Jan  2096  41  8.341410  1.758964e+07
# 41   Q2_96  5253.000000 2096-04-01   Apr  2096  42  8.566555  2.759401e+07
#
#     predictions
# 0   1881.898498
# 1   2022.364801
# 2   2130.560127
# 3   2038.058968
# 4   1921.654076
# 5   2065.250722
# 6   2062.318664
# 7   2077.113572
# 8   2067.655147
# 9   2210.422238
# 10  2176.975322
# 11  2170.509851
# 12  2161.688559
# 13  2305.611855
# 14  2288.683547
# 15  2301.432044
# 16  2316.494581
# 17  2555.600348
# 18  2604.509889
# 19  2530.582896
# 20  2526.444562
# 21  2803.866178
# 22  2904.023596
# 23  2778.164760
# 24  2754.464252
# 25  3233.323103
# 26  3236.090529
# 27  3094.916177
# 28  3014.690668
# 29  3642.468197
# 30  3457.134779
# 31  3305.400129
# 32  3323.964505
# 33  4237.382633
# 34  4418.896387
# 35  3977.795546
# 36  3862.917922
# 37  5217.954009
# 38  5205.422448
# 39  4486.478527
# 40  4369.946029
# 41  5992.587926
